# %% [markdown]
# # Low-ℓ BB — Simulation Input Sky Inspector
#
# **Task (to be defined):** Find mid-ell input sky simulations and adapt them as input skies for the low-ell mapmaker.
#
# **Open questions before writing any code:**
#
# 1. What is inside `simulated_maps/` in the mid-ell data directory?
#    Run this on the HPC to find out:
#    ```python
#    import os
#    SIM_DIR = "/sptgrid/analysis/spt3g_d1_midell_tqu_healpix/simulated_maps"
#    for root, dirs, files in os.walk(SIM_DIR):
#        level = root.replace(SIM_DIR, "").count(os.sep)
#        indent = "  " * level
#        print(f"{indent}{os.path.basename(root)}/")
#        if level < 2:
#            for f in files[:5]:
#                print(f"{indent}  {f}")
#    ```
#
# 2. What is the **low-ell mapmaker**? Is it a specific SPT3G pipeline script, or something being built? This determines whether the task is reformatting/reprojecting existing simulations or generating new ones.
#
# 3. What are **mid-ell input skies** exactly — the CMB+foreground sky realizations fed into the mid-ell mapmaking pipeline (i.e., signal before instrument noise), or something else?
#
# 4. What format does the low-ell mapmaker expect as input — g3, FITS, HEALPix at a specific nside, flat-sky?
#
# 5. How many simulations are needed?
